# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from mpl_toolkits.mplot3d import Axes3D, axes3d
import numpy as np

# %matplotlib inline

# %%
train = pd.read_csv("../input/train.csv")
# weather = pd.read_csv("../../rrm/riordan/data/weather.csv")

# %%
train.dropna(inplace=True)

# %%
ddd_data = train[["Date","WnvPresent","Latitude","Longitude","NumMosquitos"]]

# %%
ddd_data["Date"] = pd.to_datetime(ddd_data["Date"])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from datetime import datetime

for year in [2007, 2009, 2011, 2013]:
    ddd = ddd_data[((ddd_data['Date'] > str((year - 1))) & (ddd_data['Date'] < str((year + 1))))]
    fig = plt.figure(figsize=(20,16))
    ax = fig.gca(projection='3d')

    z = ddd["Longitude"].values.tolist()
    x = ddd["Date"].values.tolist()
    y = ddd["Latitude"].values.tolist()
    s = [x*x for x in ddd["NumMosquitos"].values.tolist()]
    print(set(ddd["Date"].dt.date))
#     date_range = [datetime.utcfromtimestamp(int(date/10000000000)) for date in np.linspace(int(min(x)), int(max(x)), num=6)]

#     c = [[x, (1 - x), (1 - x), (1 if x == 1 else .1)] for x in ddd["WnvPresent"].values.tolist()]
#     plt.xscale("linear")
#     plt.title(f"LatLong WnvPresent for {year}")
# #     ax.xaxis.set_ticklabels(date_range)
#     ax.scatter(x, y, z, label='West Nile Virus', s=s, c=c)
# Out:
# {datetime.date(2007, 9, 5), datetime.date(2007, 8, 8), datetime.date(2007, 9, 25), datetime.date(2007, 8, 9), datetime.date(2007, 6, 26), datetime.date(2007, 8, 3), datetime.date(2007, 7, 11), datetime.date(2007, 8, 15), datetime.date(2007, 7, 2), datetime.date(2007, 9, 4), datetime.date(2007, 8, 21), datetime.date(2007, 7, 18), datetime.date(2007, 8, 24), datetime.date(2007, 9, 6), datetime.date(2007, 10, 4), datetime.date(2007, 6, 29), datetime.date(2007, 6, 5), datetime.date(2007, 9, 24), datetime.date(2007, 5, 29), datetime.date(2007, 10, 9), datetime.date(2007, 9, 12), datetime.date(2007, 7, 27), datetime.date(2007, 8, 22), datetime.date(2007, 8, 16), datetime.date(2007, 8, 1), datetime.date(2007, 8, 7), datetime.date(2007, 9, 19), datetime.date(2007, 7, 19), datetime.date(2007, 8, 17), datetime.date(2007, 8, 2), datetime.date(2007, 8, 28), datetime.date(2007, 7, 25), datetime.date(2007, 9, 18)}
# {datetime.date(2009, 6, 15), datetime.date(2009, 6, 3), datetime.date(2009, 8, 27), datetime.date(2009, 7, 31), datetime.date(2009, 8, 13), datetime.date(2009, 6, 5), datetime.date(2009, 9, 17), datetime.date(2009, 6, 22), datetime.date(2009, 7, 6), datetime.date(2009, 6, 2), datetime.date(2009, 7, 27), datetime.date(2009, 9, 14), datetime.date(2009, 6, 29), datetime.date(2009, 6, 19), datetime.date(2009, 7, 24), datetime.date(2009, 7, 17), datetime.date(2009, 6, 12), datetime.date(2009, 9, 25), datetime.date(2009, 9, 3), datetime.date(2009, 7, 10), datetime.date(2009, 5, 28), datetime.date(2009, 8, 25), datetime.date(2009, 8, 7), datetime.date(2009, 6, 26), datetime.date(2009, 7, 13), datetime.date(2009, 10, 1)}
# {datetime.date(2011, 6, 30), datetime.date(2011, 8, 19), datetime.date(2011, 9, 12), datetime.date(2011, 6, 10), datetime.date(2011, 8, 5), datetime.date(2011, 9, 16), datetime.date(2011, 9, 30), datetime.date(2011, 9, 23), datetime.date(2011, 8, 12), datetime.date(2011, 7, 11), datetime.date(2011, 7, 15), datetime.date(2011, 8, 26), datetime.date(2011, 6, 17), datetime.date(2011, 7, 25), datetime.date(2011, 9, 1), datetime.date(2011, 9, 2), datetime.date(2011, 7, 29), datetime.date(2011, 6, 24)}
# {datetime.date(2013, 9, 6), datetime.date(2013, 6, 21), datetime.date(2013, 8, 22), datetime.date(2013, 8, 29), datetime.date(2013, 6, 28), datetime.date(2013, 7, 19), datetime.date(2013, 6, 7), datetime.date(2013, 7, 25), datetime.date(2013, 7, 12), datetime.date(2013, 8, 15), datetime.date(2013, 9, 12), datetime.date(2013, 9, 26), datetime.date(2013, 7, 8), datetime.date(2013, 9, 19), datetime.date(2013, 8, 8), datetime.date(2013, 6, 27), datetime.date(2013, 8, 1), datetime.date(2013, 6, 14)}
