# %% [markdown]
# # Using Linear Regression to Predict Number of Mosquitos
#
# ### This notebook is to explore how to predict number of mosquitos so that we can use this as a feature for predicting the presence of West Nile Virus

# %% [markdown]
# First, let's import some dependencies for numerical calculations; create and manipulate data; train and test our machine learning algorithms; something to scale our data; and import our Linear Regression model that we will use to predict the number of mosquitos.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.dummy import DummyRegressor
from sklearn.svm import SVR

from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# Next, we will import our training and test data

# %%
train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")

# %% [markdown]
# We are going to create a function for removing columns/creating new dummy columns

# %%
def create_month(x):
    return int(x.split('-')[1])

def create_day(x):
    return int(x.split('-')[2])

def transform_df(df):
    # Turn month, date into features
    df['month'] = df["Date"].apply(create_month)
    df['day'] = df["Date"].apply(create_day)
    df.drop(columns=["Street", "Address", "AddressAccuracy", "Date","Species","AddressNumberAndStreet"], inplace=True)
    return pd.get_dummies(df, columns=["Trap"])

train = transform_df(train)

# %% [markdown]
# I am not going to do too much feature selection for now; will do a basic train-test split and then perform the same on the test data

# %%
X = train.drop(columns=["NumMosquitos"])
y = train["NumMosquitos"]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.fit_transform(X_test)

# %%
models_and_penalties = [
    LinearRegression(),
    Lasso(alpha=.05,normalize=True, max_iter=1e5),
    Ridge(alpha=1,normalize=True, max_iter=1e5),
    ElasticNet(alpha=.01,max_iter=1e5)
]

# %%
for model in models_and_penalties:
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_train_scaled)
    test_preds = model.predict(X_test_scaled)
    print(f"Predicted {sum(preds)} total number of mosquitos for the training data")
    print(f"Predicted {sum(test_preds)} total number of mosquitos for the testing data")
    print(f"Actual is {train.NumMosquitos.sum()}")
    print()
    print(f"Mean Squared Error for train data: {mean_squared_error(y_train, preds)}")
    print(f"Mean Squared Error for test data: {mean_squared_error(y_test, test_preds)}")
    print()
    print()
# Out:
# Predicted 100626.14221319814 total number of mosquitos for the training data
# Predicted 33038.427642822266 total number of mosquitos for the testing data
# Actual is 135039
#
# Mean Squared Error for train data: 163.46031591017302
# Mean Squared Error for test data: 2.084878551720714e+23
#
#
# Predicted 100633.00000001147 total number of mosquitos for the training data
# Predicted 33552.848204086215 total number of mosquitos for the testing data
# Actual is 135039
#
# Mean Squared Error for train data: 238.77900346445094
# Mean Squared Error for test data: 244.10026097374276
#
#
# Predicted 100633.00000000044 total number of mosquitos for the training data
# Predicted 33552.84820408697 total number of mosquitos for the testing data
# Actual is 135039
#
# Mean Squared Error for train data: 183.75954231869144
# Mean Squared Error for test data: 192.75389384463708
#
#
# Predicted 100632.99999999994 total number of mosquitos for the training data
# Predicted 33552.84820408725 total number of mosquitos for the testing data
# Actual is 135039
#
# Mean Squared Error for train data: 163.49397435779377
# Mean Squared Error for test data: 174.51814203526453

# %%
# borrowed from https://www.programcreek.com/python/example/85938/sklearn.ensemble.BaggingRegressor
grid = ParameterGrid({"max_samples": [0.5, 1.0],
                          "max_features": [0.5, 1.0],
                          "bootstrap": [True, False],
                          "bootstrap_features": [True, False]})

for base_estimator in [None,
                           DummyRegressor(),
                           DecisionTreeRegressor(),
                           KNeighborsRegressor(),
                           SVR()]:
    for params in grid:
        br = BaggingRegressor(base_estimator=base_estimator,
                         **params).fit(X_train, y_train)
        pred = br.predict(X_train)
        test_preds = br.predict(X_test)
        print(f"Scores for {str(base_estimator)} and {params}")
        print(f"Mean Squared Error for train data: {mean_squared_error(y_train, preds)}")
        print(f"Mean Squared Error for test data: {mean_squared_error(y_test, test_preds)}")
        [print() for _ in range(5)]
# Out:
# Scores for None and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 122.76840517378167
# Mean Squared Error for test data: 160.11653495368537
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 137.30020711496633
# Mean Squared Error for test data: 156.82911500757916
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 100.91531733338975
# Mean Squared Error for test data: 140.7384786370963
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 93.73972535766899
# Mean Squared Error for test data: 138.8047491998493
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 105.4920248881923
# Mean Squared Error for test data: 150.34444208187819
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 113.0845337584873
# Mean Squared Error for test data: 136.70424322962455
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 87.15139723640107
# Mean Squared Error for test data: 142.91170743632858
#
#
#
#
#
# Scores for None and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 74.92992680441117
# Mean Squared Error for test data: 141.6973413186285
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 125.05458742032582
# Mean Squared Error for test data: 149.34150561127802
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 117.92483058021422
# Mean Squared Error for test data: 143.4919609129165
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 91.95578331738463
# Mean Squared Error for test data: 134.9508843027202
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 81.81050190095606
# Mean Squared Error for test data: 136.58854638080672
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 109.00294539107803
# Mean Squared Error for test data: 150.454073215528
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 106.1302540731461
# Mean Squared Error for test data: 135.5930529222169
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 80.95850742005364
# Mean Squared Error for test data: 140.2721520822878
#
#
#
#
#
# Scores for None and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 66.7471060488044
# Mean Squared Error for test data: 156.7943877532217
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.89403538403866
# Mean Squared Error for test data: 264.4267532743878
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.8937285621314
# Mean Squared Error for test data: 264.4162525124415
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.8889781378332
# Mean Squared Error for test data: 264.500161516363
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.88946370604344
# Mean Squared Error for test data: 264.43576915762054
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.9062302381072
# Mean Squared Error for test data: 264.4354711692446
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.9061599682893
# Mean Squared Error for test data: 264.45316100928017
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.89681926840757
# Mean Squared Error for test data: 264.5452592534509
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.89422661185506
# Mean Squared Error for test data: 264.48199478532365
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.8889420797545
# Mean Squared Error for test data: 264.4496387819318
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.88888402051197
# Mean Squared Error for test data: 264.45958103186734
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.8926620669771
# Mean Squared Error for test data: 264.48910520960857
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.88888402051197
# Mean Squared Error for test data: 264.45958103186734
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.88980726315316
# Mean Squared Error for test data: 264.47691325099635
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.88888402051197
# Mean Squared Error for test data: 264.45958103186734
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 258.88888505887604
# Mean Squared Error for test data: 264.4486526701425
#
#
#
#
#
# Scores for DummyRegressor(constant=None, quantile=None, strategy='mean') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 258.88888402051197
# Mean Squared Error for test data: 264.45958103186734
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 119.60706300630862
# Mean Squared Error for test data: 151.87651572587734
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 125.87951273360127
# Mean Squared Error for test data: 149.99895219691373
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 101.79559741079426
# Mean Squared Error for test data: 142.52343254598347
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 90.06264773206921
# Mean Squared Error for test data: 149.14319734666583
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 123.42150343268166
# Mean Squared Error for test data: 142.15567195635757
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 112.16582660747761
# Mean Squared Error for test data: 135.21630250099344
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 87.83090550870446
# Mean Squared Error for test data: 142.9453017370171
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 74.7602354066267
# Mean Squared Error for test data: 137.57459599009368
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 132.45225980499202
# Mean Squared Error for test data: 157.82894169672394
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 105.61431300935662
# Mean Squared Error for test data: 137.62790962224412
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 116.8909782201195
# Mean Squared Error for test data: 133.82394623050845
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 88.27746008153335
# Mean Squared Error for test data: 132.3571983529281
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 114.29569468309704
# Mean Squared Error for test data: 142.99309827818078
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 106.27966187592051
# Mean Squared Error for test data: 151.18128140028153
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 80.94760379982523
# Mean Squared Error for test data: 141.18653907977586
#
#
#
#
#
# Scores for DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 66.7471060488044
# Mean Squared Error for test data: 156.2573417748634
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 151.2039598933875
# Mean Squared Error for test data: 161.9346513894176
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 125.02251336464019
# Mean Squared Error for test data: 146.3109644461363
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 129.8508019799467
# Mean Squared Error for test data: 144.31852470498666
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 106.92548424927021
# Mean Squared Error for test data: 145.74619885801295
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 132.411272750349
# Mean Squared Error for test data: 148.507365207461
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 123.62940149765198
# Mean Squared Error for test data: 156.8813437381043
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 132.31253651478613
# Mean Squared Error for test data: 162.90172303007233
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 108.69049097601219
# Mean Squared Error for test data: 157.00330795584316
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 152.2708943774591
# Mean Squared Error for test data: 157.1390350970689
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 118.64268831069931
# Mean Squared Error for test data: 144.39586509326227
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 127.42707597410839
# Mean Squared Error for test data: 144.06859748762847
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 117.24132920421374
# Mean Squared Error for test data: 139.90196939474686
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 137.32023241528114
# Mean Squared Error for test data: 163.129945793681
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 125.98655387739561
# Mean Squared Error for test data: 147.98124735439666
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 131.61200025383934
# Mean Squared Error for test data: 160.92218561096306
#
#
#
#
#
# Scores for KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='uniform') and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 112.28311207005967
# Mean Squared Error for test data: 161.33049105443473
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 307.2738188728551
# Mean Squared Error for test data: 303.68066940637317
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 290.40248094496854
# Mean Squared Error for test data: 299.81173801594053
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 294.08329371309964
# Mean Squared Error for test data: 305.3029340994829
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 288.6195274894462
# Mean Squared Error for test data: 296.857951125092
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 299.79654661220854
# Mean Squared Error for test data: 310.9302862471065
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 293.9343819182711
# Mean Squared Error for test data: 304.18204555660554
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 293.19401748310327
# Mean Squared Error for test data: 301.29133703546984
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': True, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 286.8468958263298
# Mean Squared Error for test data: 294.61226216549466
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 285.87155037438157
# Mean Squared Error for test data: 314.9746960326796
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 286.02303508089824
# Mean Squared Error for test data: 302.68822271629676
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 303.47734247934494
# Mean Squared Error for test data: 305.8505972698846
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': True, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 291.5606117008767
# Mean Squared Error for test data: 301.7110475341685
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5}
# Mean Squared Error for train data: 298.54429855149453
# Mean Squared Error for test data: 303.41304302698154
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0}
# Mean Squared Error for train data: 294.9543795071313
# Mean Squared Error for test data: 295.9428082428463
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5}
# Mean Squared Error for train data: 291.96677097183505
# Mean Squared Error for test data: 301.4213994709224
#
#
#
#
#
# Scores for SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) and {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0}
# Mean Squared Error for train data: 286.49201258445004
# Mean Squared Error for test data: 294.8073783875966
